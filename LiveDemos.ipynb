# %% [markdown]
# ## From Code to Connection: How to Deliver Technical Live Demos That Stick

# %% [markdown]
# #### Viviana Márquez, AI Developer Relations Engineer @ Prolific

# %% [markdown]
# January 22, 2026 | The Content Playbook: Smarter Data, AI, Global Docs

# %% [markdown]
# ### Agenda
#
# - Why live demos?
# - Tips for live coding well
# - Live demo
# - Live demo framework
# - Practical tool: `RISE`

# %% [markdown]
# ## Live demos aren't a replacement for documentation.
# ## They're how you make the content stick.

# %% [markdown]
# You've written beautiful docs. Clear steps, good examples, nice screenshots. And then you watch someone ignore them entirely and ask you to just show them how it works.
#
# Live demos aren't a replacement for documentation. They're a delivery mechanism for it. They're how you make the content stick and drive adoption.

# %% [markdown]
# ## Why live demos?

# %% [markdown]
# - They build credibility (the code actually runs)

# %% [markdown]
# - They're flexible to audience questions

# %% [markdown]
# - They teach process, not just outcomes

# %% [markdown]
# - They're memorable

# %% [markdown]
# Know when to use a GIF instead: If the setup is fragile, if the audience doesn't need to see execution, or if time is extremely constrained.

# %% [markdown]
# ## Tips for Live Coding Well

# %% [markdown]
# - Prepare like it's improvised

# %% [markdown]
# Practice the exact sequence (even if you've done it before.) Have recovery points. Seed your randomness.

# %% [markdown]
# - Narrate constantly

# %% [markdown]
# Silence while typing is death. Speak your thought process out loud.

# %% [markdown]
# - Fail gracefully and usefully

# %% [markdown]
# If something breaks, treat it as a teaching moment. Walk through the error. This is actually where live demos shine over docs.

# %% [markdown]
# ## Live demo

# %% [markdown]
# > “Create a slide explaining cats.”

# %% [markdown]
# Below, two AI-generated slides created in response to the prompt above:
#
# <div style="display:flex; justify-content:center;">
#   <div style="text-align:center; margin:0 40px;">
#     <img src="cats/option1.jpg" width="700" style="display:block;">
#     <b>Option 1</b>
#   </div>
#   <div style="text-align:center; margin:0 40px;">
#     <img src="cats/option2.jpg" width="700" style="display:block;">
#     <b>Option 2</b>
#   </div>
# </div>
# <br>

# %%
# Prolific setup and authentication

import os
import json
import yaml
import requests

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode

import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)

from prolific_helpers import (
    get_researcher_id,
    create_external_study,
    publish_study,
    show_study_results,
    plot_survey_responses,
    plot_responses_by_generation,
    plot_responses_by_gender,
    age_to_generation,
    create_all_option_visualizations,
    fetch_and_visualize_survey_results
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Load configuration
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)
    
from dotenv import load_dotenv
load_dotenv()

prolific_token = os.environ.get('PROLIFIC_API_TOKEN')
prolific_workspace = os.environ.get('PROLIFIC_WORKSPACE_ID')
prolific_project = os.environ.get('PROLIFIC_PROJECT_ID')

# Set up headers for authenticated requests to the Prolific API
headers = {
    "Authorization": f"Token {prolific_token}",
    "Content-Type": "application/json",
}

# Fetch your Prolific researcher ID
researcher_id = get_researcher_id(headers)

# %% [markdown]
# #### Step 1: Authenticate via Prolific's API

# %%
# Fetch your Prolific researcher ID
researcher_id = get_researcher_id(headers)
print(f"Authenticated. Researcher ID: {researcher_id}")
# Out:
# Authenticated. Researcher ID: 6866dccc753654157fe0da40

# %%
# Verify external study URL from config
external_study_url = config['study'].get('external_study_url')

if not external_study_url:
    raise ValueError("external_study_url not found in config.yaml. Please set it in the study section.")

# %% [markdown]
# #### Step 2: Publish task

# %%
# Prepare study configuration from config.yaml
study_config = {
    "name": config['study']['name'],
    "description": config['study']['description'],
    "privacy_notice": config['study']['privacy_notice'],
    "reward": config['participants']['reward'],
    "participants": config['participants']['total_participants'],
    "estimated_time": config['participants']['estimated_time'],
    "max_time": config['participants']['max_time'],
    "device_compatibility": config['device_compatibility']
}

print(study_config)
# Out:
# {'name': 'Quick & Easy: Choose Between Two Images', 'description': 'This is a very short task. You will see two AI-generated images and answer one multiple-choice question: simply choose the image you prefer. The task takes less than a minute and has no right or wrong answers.', 'privacy_notice': 'Your data will be used for research purposes only and will be kept confidential.', 'reward': 2, 'participants': 10, 'estimated_time': 2, 'max_time': 5, 'device_compatibility': ['desktop', 'tablet', 'mobile']}

# %%
# Create study using external study URL
study_id = create_external_study(
    headers=headers,
    external_study_url=external_study_url,
    study_config=study_config,
    project_id=prolific_project
)
print(f"Study created with ID: {study_id}")
# Out:
# Study created with ID: 69718f802306c7c242f82e9e

# %%
# Publish study using helper function
status_code = publish_study(headers, study_id)
print(f"Study published with status code: {status_code}")
# Out:
# Study published with status code: 200

# %% [markdown]
# #### Step 3: Get results

# %%
# Fetch and display study results using helper function and configured timezone
df = show_study_results(study_id, headers, config['timezone'])
# Out:
# ✅ Study Name: Quick & Easy: Choose Between Two Images
# 📊 Status: ACTIVE
# 👥 Total Places: 10
# 📩 Total Submissions: 6
# ⏳ Created at: 21 Jan 2026, 06:46 PM PST
# 🕒 Last Response At: 21 Jan 2026, 06:48 PM PST
# ⏱️ Time Lapsed: 3 minutes

# %%
# Fetch Prolific data and create visualizations
merged_df, figures = fetch_and_visualize_survey_results(config, df)
# Out:
# <div>                            <div id="2d7e7ec9-36be-46dc-b159-f51bfc460012" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d7e7ec9-36be-46dc-b159-f51bfc460012")) {                    Plotly.newPlot(                        "2d7e7ec9-36be-46dc-b159-f51bfc460012",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Option 1","Option 2"],"legendgroup":"","name":"","showlegend":true,"values":[3,1],"type":"pie","marker":{"colors":["#6366F1","#10B981"]},"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar" ...
# <div>                            <div id="04d205de-a767-4307-ad3d-39cd4498d40f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04d205de-a767-4307-ad3d-39cd4498d40f")) {                    Plotly.newPlot(                        "04d205de-a767-4307-ad3d-39cd4498d40f",                        [{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 1\u003cbr\u003eSex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 1","marker":{"color":"#6366F1","pattern":{"shape":""}},"name":"Option 1","offsetgroup":"Option 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male"],"xaxis":"x","y":[3,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 2\u003cbr\u003eSex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 2","marker":{"color":"#10B981","pattern":{"shape":""}},"name":"Option 2","offsetgroup":"Option 2","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male"],"xaxis":"x","y":[0,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewid ...
# <div>                            <div id="205b78d9-bdd9-4616-95e8-d7ca31759406" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("205b78d9-bdd9-4616-95e8-d7ca31759406")) {                    Plotly.newPlot(                        "205b78d9-bdd9-4616-95e8-d7ca31759406",                        [{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 1\u003cbr\u003eGeneration=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 1","marker":{"color":"#6366F1","pattern":{"shape":""}},"name":"Option 1","offsetgroup":"Option 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Gen Z (18-27)"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 2\u003cbr\u003eGeneration=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 2","marker":{"color":"#10B981","pattern":{"shape":""}},"name":"Option 2","offsetgroup":"Option 2","orientation":"v","showlegend":true,"textposition":"auto","x":["Gen Z (18-27)"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{" ...
# <div>                            <div id="1629b4a8-8278-4918-befb-155560b02d6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1629b4a8-8278-4918-befb-155560b02d6e")) {                    Plotly.newPlot(                        "1629b4a8-8278-4918-befb-155560b02d6e",                        [{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 1\u003cbr\u003eCountry_Group=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 1","marker":{"color":"#6366F1","pattern":{"shape":""}},"name":"Option 1","offsetgroup":"Option 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Others","USA"],"xaxis":"x","y":[2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Slide Option=Option 2\u003cbr\u003eCountry_Group=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Option 2","marker":{"color":"#10B981","pattern":{"shape":""}},"name":"Option 2","offsetgroup":"Option 2","orientation":"v","showlegend":true,"textposition":"auto","x":["Others","USA"],"xaxis":"x","y":[1,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colo ...
# ================================================================================
# All Comments (1 total):
# ================================================================================
#
# Comment 1: no

# %% [markdown]
# ## Live demo - Framework

# %% [markdown]
# - What's the need?

# %% [markdown]
# Know your audience. What problem do they wake up thinking about? If you don't know this, your demo is a performance, not a solution.

# %% [markdown]
# - What's the solution?

# %% [markdown]
# Show how your thing solves that specific problem. Not every feature. Just: here's your pain, here's relief.

# %% [markdown]
# - What's the next step?

# %% [markdown]
# You don't need to show everything. Show the most impressive part, then give them a place to go: GitHub, docs, a follow-up meeting. The demo opens the door; it doesn't need to give the full tour.

# %% [markdown]
# ## Practical tool: `RISE`

# %% [markdown]
# - It turns Jupyter notebooks into interactive slideshows where you can run code live

# %% [markdown]
# - Documentation: https://rise.readthedocs.io/

# %% [markdown]
# ## How does `RISE` work?

# %% [markdown]
# Installation:
# - Current (using Jupyter Lab):
#
# `conda create -n rise_slides python=3.14 jupyterlab jupyterlab_rise -c conda-forge`
# - Deprecated (using Jupyter Notebook):
#
# `conda create -n rise_slides python=3.10 notebook=6.5.4 "tinycss2<1.5" rise -c conda-forge`

# %% [markdown]
# ## General tips when using `RISE`

# %% [markdown]
# - Build incrementally. Use fragments strategically

# %% [markdown]
# - Put setup code in skipped cells and run it beforehand

# %% [markdown]
# - Use Markdown for cells for text

# %% [markdown]
# ## Let's connect
#
# - 📊 Slides: [https://github.com/vivianamarquez/Technical-Live-Demos-That-Stick](https://github.com/vivianamarquez/Technical-Live-Demos-That-Stick)
# - 💼 LinkedIn: [/in/vivianamarquez](https://www.linkedin.com/in/vivianamarquez)
# - 🐙 GitHub: [@vivianamarquez](https://github.com/vivianamarquez)
#
# **Viviana Márquez** | AI Developer Relations Engineer @ Prolific
